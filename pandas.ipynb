# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(df.head()) #top 5 rows
print(df.tail()) #last 5 rows
print(df.shape) #number of rows and columns
print(df.columns) #column names
print(df.info()) #summary of the dataFrame
print(df.describe()) #summary statistics for numerical columns
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# ...

# %% [markdown]
# Accessing Data

# %%
#single column access
print(df['pclass'])
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
#multiple column access
print(df[['pclass','age']])
# Out:
#      pclass   age
# 0         3  22.0
# 1         1  38.0
# 2         3  26.0
# 3         1  35.0
# 4         3  35.0
# ..      ...   ...
# 886       2  27.0
# 887       1  19.0
# 888       3   NaN
# 889       1  26.0
# 890       3  32.0
#
# [891 rows x 2 columns]

# %%
#access rows using index position
df.iloc[78] #78 means the 79th row (0-based index)
# Out:
# survived                 1
# pclass                   2
# sex                   male
# age                   0.83
# sibsp                    0
# parch                    2
# fare                  29.0
# embarked                 S
# class               Second
# who                  child
# adult_male           False
# deck                   NaN
# embark_town    Southampton
# alive                  yes
# alone                False
# Name: 78, dtype: object

# %%
df.iloc[[0,2,4,6]] #
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 4    man        True  NaN  Southampton    no   True
# 6    man        True    E  Southampton    no   True

# %%
df.iloc[2:11:2] #slicing from 2 to 10 and gap is 2
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 2          1       3  female  26.0      0      0   7.9250        S  Third
# 4          0       3    male  35.0      0      0   8.0500        S  Third
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 8          1       3  female  27.0      0      2  11.1333        S  Third
# 10         1       3  female   4.0      1      1  16.7000        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 2   woman       False  NaN  Southampton   yes   True
# 4     man        True  NaN  Southampton    no   True
# 6     man        True    E  Southampton    no   True
# 8   woman       False  NaN  Southampton   yes  False
# 10  child       False    G  Southampton   yes  False

# %%
df=df.set_index('pclass') #vaise to id ko index banateh par isme h nhi...unique value ko hi index banate hai..kchouse.csv wala dataset use karte hai
df.head()
# Out:
#         survived     sex   age  sibsp  parch     fare embarked  class    who  \
# pclass
# 3              0    male  22.0      1      0   7.2500        S  Third    man
# 1              1  female  38.0      1      0  71.2833        C  First  woman
# 3              1  female  26.0      0      0   7.9250        S  Third  woman
# 1              1  female  35.0      1      0  53.1000        S  First  woman
# 3              0    male  35.0      0      0   8.0500        S  Third    man
#
#         adult_male deck  embark_town alive  alone
# pclass
# 3             True  NaN  Southampton    no  False
# 1            False    C    Cherbourg   yes  False
# 3            False  NaN  Southampton   yes   True
# 1            False    C  Southampton   yes  False
# 3             True  NaN  Southampton    no   True

# %% [markdown]
# Data Cleaning

# %%
print(df.isnull().sum()) #count of null values in each column
# Out:
# survived         0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# - data handling and data deletion two ways to handle the null valus in a dataset
# - use data handling if column is important
# - use data deletion if column is not important

# %% [markdown]
# - handling : fillna
# - whole column delete : drop
# - null columns delete : dropna

# %%
df['age'].fillna(df['age'].mean(),inplace=True) #fill null values in 'age' with mean
# Out:
# C:\Users\saumy\AppData\Local\Temp\ipykernel_15348\2923658010.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(),inplace=True) #fill null values in 'age' with mean

# %% [markdown]
# filtering data

# %%
adults = df[df['age']>=18]
#print(adults)
females = df[df['sex']=='female']
females = df[df['survived']==1]
print(females)
# Out:
#         survived     sex   age  sibsp  parch     fare embarked   class    who  \
# pclass
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 3              1  female  26.0      0      0   7.9250        S   Third  woman
# 1              1  female  35.0      1      0  53.1000        S   First  woman
# 3              1  female  27.0      0      2  11.1333        S   Third  woman
# 2              1  female  14.0      1      0  30.0708        C  Second  child
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 3              1  female  15.0      0      0   7.2250        C   Third  child
# 1              1  female  56.0      0      1  83.1583        C   First  woman
# 2              1  female  25.0      0      1  26.0000        S  Second  woman
# 1              1  female  19.0      0      0  30.0000        S   First  woman
# 1              1    male  26.0      0      0  30.0000        C   First    man
#
# ...
